# %%
print("hello world")
# Out:
# hello world

# %%
help
# Out:
# Type help() for interactive help, or help(object) for help about object.

# %%
import pandas as pd

# %%
iris_data = pd.read_csv('iris-data.csv',na_values=[''])
#'', na_values=['NA'])

# %%
iris_data.head()
#iris_data.head(50)
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
import pandas as pd

iris_data = pd.read_csv('iris-data.csv')
iris_data.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
iris_data = pd.read_csv('iris-data.csv', na_values=['NA'])

# %%
iris_data.head(15)
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0               5.1             3.5              1.4             0.2
# 1               4.9             3.0              1.4             0.2
# 2               4.7             3.2              1.3             0.2
# 3               4.6             3.1              1.5             0.2
# 4               5.0             3.6              1.4             0.2
# 5               5.4             3.9              1.7             0.4
# 6               4.6             3.4              1.4             0.3
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
# 12              4.8             3.0              1.4             0.1
# 13              5.7             3.0              1.1             0.1
# 14              5.8             4.0              1.2             0.2
#
#           class
# 0   Iris-setosa
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa
# 6   Iris-setosa
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa
# 12  Iris-setosa
# 13  Iris-setosa
# 14  Iris-setosa

# %%
iris_data.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
sb.pairplot(iris_data.dropna(), hue='class')

# %%
# fixing class labels. there were some spelling mistakes in class labels
iris_data.loc[iris_data['class']=='versicolor','class'] ='Iris-versicolor'
iris_data.loc[iris_data['class']=='Iris-setossa','class']='Iris-setosa'

# %%
iris_data['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#iris_data.loc[(iris_data['class'] != 'Iris-setosa')]

# %%
#iris_data.loc[iris_data['sepal_width_cm'] >= 2.5]
iris_data.loc[iris_data['class'] == 'Iris-setosa', 'sepal_width_cm'].hist()

# %%
# removes single outlier of setosa (a single blue dot seen in fig) 
iris_data = iris_data.loc[(iris_data['class'] != 'Iris-setosa') | (iris_data['sepal_width_cm'] >= 2.5)]
iris_data
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# 5                5.4             3.9              1.7             0.4
# 6                4.6             3.4              1.4             0.3
# 7                5.0             3.4              1.5             NaN
# 8                4.4             2.9              1.4             NaN
# 9                4.9             3.1              1.5             NaN
# 10               5.4             3.7              1.5             NaN
# 11               4.8             3.4              1.6             NaN
# 12               4.8             3.0              1.4             0.1
# 13               5.7             3.0              1.1             0.1
# 14               5.8             4.0              1.2             0.2
# 15               5.7             4.4              1.5             0.4
# 16               5.4             3.9              1.3             0.4
# 17               5.1             3.5              1.4             0.3
# 18               5.7             3.8              1.7             0.3
# 19               5.1             3.8              1.5             0.3
# 20               5.4             3.4              1.7             0.2
# 21               5.1             3.7              1.5             0.4
# 22               4.6             3.6              1.0             0.2
# 23               5.1             3.3              1.7             0.5
# 24               4.8             3.4              1.9             0.2
# 25               5.0             3.0              1.6             0.2
# 26               5.0             3.4              1.6             0.4
# 27               5.2             3.5              1.5             0.2
# 28               5.2             3.4              1.4             0.2
# 29               4.7             3.2              1.6             0.2
# ..               ...             ...              ...             ...
# 120              6.9             3.2              5.7             2.3
# 121              5.6             2.8              4.9             2.0
# 122              5.6             2.8              6.7             2.0
# 123              6.3             2.7              4.9             1.8
# 124              6.7             3.3              5.7             2.1
# 125              7.2             3.2              6.0             1.8
# 126              6.2             2.8              4.8             1.8
# 127              6.1             3.0              4.9             1.8
# 128              6.4             2.8              5.6             2.1
# 129              7.2             3.0              5.8             1.6
# 130              7.4             2.8              6.1             1.9
# 131              7.9             3.8              6.4             2.0
# 132              6.4             2.8              5.6             2.2
# 133              6.3             2.8              5.1             1.5
# 134              6.1             2.6              5.6             1.4
# 135              7.7             3.0              6.1             2.3
# 136              6.3             3.4              5.6             2.4
# 137              6.4             3.1              5.5             1.8
# 138              6.0             3.0              4.8             1.8
# 139              6.9             3.1              5.4             2.1
# 140              6.7             3.1              5.6             2.4
# 141              6.9             3.1              5.1             2.3
# 142              5.8             2.7              5.1             1.9
# 143              6.8             3.2              5.9             2.3
# 144              6.7             3.3              5.7             2.5
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 120  Iris-virginica
# 121  Iris-virginica
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [149 rows x 5 columns]

# %%
# can see the outlier of setosa gone
iris_data.loc[iris_data['class'] == 'Iris-setosa', 'sepal_width_cm'].hist()

# %%
# THERE seems to be some outliers. But from the csv file we can see that those values have beeen entered in metres, while r
# rest are entered in centimetres. So changing m to cm
iris_data.loc[(iris_data['class']=='Iris-versicolor') & (iris_data['sepal_length_cm'] <1) ]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 77            0.067             3.0              5.0             1.7
# 78            0.060             2.9              4.5             1.5
# 79            0.057             2.6              3.5             1.0
# 80            0.055             2.4              3.8             1.1
# 81            0.055             2.4              3.7             1.0
#
#               class
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor

# %%
iris_data.loc[(iris_data['class']=='Iris-versicolor') & (iris_data['sepal_length_cm'] <1.0), 'sepal_length_cm' ] *=100.0

# %%
iris_data.loc[iris_data['class']=='Iris-versicolor', 'sepal_length_cm'].hist()

# %%
# checking all 4 attributes for null values
iris_data.loc[(iris_data['sepal_length_cm'].isnull()) |
             (iris_data['sepal_width_cm'].isnull()) |
            (iris_data['petal_length_cm'].isnull()) |
            (iris_data['petal_width_cm'].isnull())]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
# viewing all the petal widths for the class 'Iris-setosa'
iris_data.loc[(iris_data['class']=='Iris-setosa','petal_width_cm')]
# Out:
# 0     0.2
# 1     0.2
# 2     0.2
# 3     0.2
# 4     0.2
# 5     0.4
# 6     0.3
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    0.1
# 13    0.1
# 14    0.2
# 15    0.4
# 16    0.4
# 17    0.3
# 18    0.3
# 19    0.3
# 20    0.2
# 21    0.4
# 22    0.2
# 23    0.5
# 24    0.2
# 25    0.2
# 26    0.4
# 27    0.2
# 28    0.2
# 29    0.2
# 30    0.2
# 31    0.4
# 32    0.1
# 33    0.2
# 34    0.1
# 35    0.2
# 36    0.2
# 37    0.1
# 38    0.2
# 39    0.2
# 40    0.3
# 41    0.3
# 42    0.2
# 43    0.6
# 44    0.4
# 45    0.3
# 46    0.2
# 47    0.2
# 48    0.2
# 49    0.2
# Name: petal_width_cm, dtype: float64

# %%
# need to replace all NaN with mean of the petal widths. So compute mean value

average_petal_width=iris_data.loc[(iris_data['class']=='Iris-setosa','petal_width_cm')].mean()

# %%
# replace NaN with mean value
iris_data.loc[(iris_data['class']=='Iris-setosa') &
              (iris_data['petal_width_cm'].isnull()), 
              'petal_width_cm']=average_petal_width

# %%
#viewing those modified entries
iris_data.loc[(iris_data['class'] == 'Iris-setosa') &
              (iris_data['petal_width_cm'] == average_petal_width)]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5        0.251111
# 8               4.4             2.9              1.4        0.251111
# 9               4.9             3.1              1.5        0.251111
# 10              5.4             3.7              1.5        0.251111
# 11              4.8             3.4              1.6        0.251111
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
'/home/nayeem/Documents/Courses/2017-18/MachineLearning/Material/Labs/PreProcessing/exp1DataPreprocessing/iris-data
# Out:
#   File "<ipython-input-34-ee53101a5fde>", line 1
#     '/home/nayeem/Documents/Courses/2017-18/MachineLearning/Material/Labs/PreProcessing/exp1DataPreprocessing/iris-data
#                                                                                                                        ^
# SyntaxError: EOL while scanning string literal

# %%
clean_data=pd.read_csv('/home/nayeem/Documents/Courses/2017-18/MachineLearning/Material/Labs/PreProcessing/exp1DataPreprocessing/iris-data-clean.csv')

# %%
sb.pairplot(clean_data,hue='class')

# %%
clean_data.mean()
# Out:
# sepal_length_cm    5.847651
# sepal_width_cm     3.059732
# petal_length_cm    3.775168
# petal_width_cm     1.209732
# dtype: float64

# %%
clean_data.median()
# Out:
# sepal_length_cm    5.8
# sepal_width_cm     3.0
# petal_length_cm    4.4
# petal_width_cm     1.3
# dtype: float64

# %%
clean_data.mode()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.0             3.0              1.5             0.2
# 1              NaN             NaN              NaN             NaN
#
#              class
# 0  Iris-versicolor
# 1   Iris-virginica

# %%
plt.figure(figsize=(10, 10))

for column_index, column in enumerate(clean_data.columns):
    if column == 'class':
        continue
    plt.subplot(2, 2, column_index + 1)
    sb.violinplot(x='class', y=column, data=clean_data)

# %%
plt.figure(figsize=(10, 10))

for column_index, column in enumerate(clean_data.columns):
    if column == 'class':
        continue
    plt.subplot(2, 2, column_index + 1)
    sb.boxplot(x='class', y=column, data=clean_data)
